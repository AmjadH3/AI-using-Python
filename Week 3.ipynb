# %% [markdown]
# ## Topic 48 What is Data and why is it Important
# ### Data Science-
#     Fundamental paradigm(Frame work) in AI in which data is studied, transformed, and used to build predictive models.
# #### Data-
#     Raw fact, figures or observation
# #### Information (Knowledge)
#     transformed data to become meaningfull,
#
# ### Primary Elements in AI Model Development
#     1st and imp is data collection form client when making a project
#     1. Domain Understanding
#     2 Extracting sufficient data for AI model creation
# ### Diffent Types of Data
# #### Structured- In table forms
#     Rows / Columns (DB, CSV), excel, easy to visiualize and easy to process, difficult for client.
# #### Unstructured-
#     Text, image, audio, video, easy to collect but difficult to process.
# #### Semi-Structued Data -
#     JSON, XML, WEB compatible,
#     json is getting famous, could be lengthy data but well defined structure and best for machine learning
# - Data is fundamental thing ai and ml. the better data th better th output,
# acts as the fuel for ml algorithms
# - Data directly imapct model accuracy and reliability
# - without queality data even advance models fail.
#
# ### Characteristics of high quality of data
# - Relevance- align with problem
# - Accuracy- error free, rliable upto 99 percent
# - Diversity - covers different cases and vriations
# - Sufficient - Enough quantity for trainning cover every case,aspect, every variation and robust(unlikely to fail) to solve every problem
#
# #### Role of Data in ML Pipeline
# - when making ml process and run it called ml pipeline and deploy for client. Process consists of
#     - Collection- Gathering of Data
#     - Pre-Processing- clean remove error and transforming into input for ml.
#     - Feature Engineering- Extract useful feature, not every feature is used so remove irrelevant of them and leave useful only and become precise.
#     - Model Training- Feeding data into alogrithms, after iteration and training
#     - Evaluation- testing model performce,

# %% [markdown]
# ### Topic 49 Introduction to NumPy, Pandas, Matplotlib & Seaborn
# #### Panda
